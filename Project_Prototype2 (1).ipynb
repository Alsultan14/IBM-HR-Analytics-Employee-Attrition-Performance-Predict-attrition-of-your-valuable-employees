# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
import seaborn as sns

# %% [markdown]
# # Step1: **Exploring the dataset**

# %%
df =pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
pd.set_option('display.float_format' ,lambda x:'%.2f' % x)


#cleaning data making sure

# %% [markdown]
# # **Being more familiar with all the data types, getting some basic info like number of columns, rows, Non-Null Count and Data type**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.sample(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1177   50        No      Travel_Rarely        813  Research & Development
# 173    30        No         Non-Travel        111  Research & Development
# 83     38        No         Non-Travel        573  Research & Development
# 1358   31        No      Travel_Rarely       1079                   Sales
# 148    41        No      Travel_Rarely        933  Research & Development
# 945    50        No      Travel_Rarely       1322  Research & Development
# 12     31        No      Travel_Rarely        670  Research & Development
# 196    35        No  Travel_Frequently        138  Research & Development
# 313    33        No  Travel_Frequently        553  Research & Development
# 744    37       Yes      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1177                17          5  Life Sciences              1
# ...

# %%
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %% [markdown]
# # Step2:**Check the data and make sure there is no outliers **

# %%
df.describe()
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
attr_1 = df.groupby('Attrition')
attr_1.mean()
# Out:
#             Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Attrition
# No        37.56     812.50              8.92       2.93           1.00
# Yes       33.61     750.36             10.63       2.84           1.00
#
#            EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# Attrition
# No                1027.66                     2.77       65.95
# Yes               1010.35                     2.46       65.57
#
#            JobInvolvement  JobLevel  ...  RelationshipSatisfaction  \
# Attrition                            ...
# No                   2.77      2.15  ...                      2.73
# Yes                  2.52      1.64  ...                      2.60
#
#            StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                 80.00              0.85              11.86
# Yes                80.00              0.53               8.24
#
#            TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# Attrition
# ...

# %%
#the data look pretty clean so far however, I will check for more cleaning in the data cleaning step

# %% [markdown]
# # Step3: **Answering the Questions**
#
# Q1) What was the ratio of negative effect on the study?

# %%
X=df.groupby(['EducationField', 'Attrition'])[["Education"]].count()

# %%
X=X.reset_index()

# %% [markdown]
# # **Qustion(1)**
# **1)what** is the most impacted field of education by attrition?

# %%
plt.figure(figsize=[10,10])
plt.bar(X.EducationField,X.Education)
plt.xlabel('Education Fileld')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %% [markdown]
# # Question (2)
# 2)**What** is the consequence of last promotion on the number of attritions?

# %%
num_s=df.groupby('YearsSinceLastPromotion').count()
plt.bar(num_s.index.values, num_s['YearsAtCompany'])
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # Question(3)
# 3)**What** is the relationship between the age and attrition?

# %%
a_s= df.groupby(['Age' , 'Attrition'])[['Attrition']].count()
a_s
# Out:
#                Attrition
# Age Attrition
# 18  No                 4
#     Yes                4
# 19  No                 3
#     Yes                6
# 20  No                 5
# ...                  ...
# 57  No                 4
# 58  No                 9
#     Yes                5
# 59  No                10
# 60  No                 5
#
# [82 rows x 1 columns]

# %% [markdown]
# # Question(4)

# %% [markdown]
#  **What** is the relationship bteween  geneder and attrition?

# %%
df.groupby(['Gender'] )[['Attrition']].count().sort_values(ascending = False , by ='Attrition')
# Out:
#         Attrition
# Gender
# Male          882
# Female        588

# %% [markdown]
# # Question(5)
# 5)**How** job role in the company effect attrition?

# %%
df.groupby(['JobRole'] )[['Attrition']].count().sort_values(ascending = True , by ='Attrition')
# Out:
#                            Attrition
# JobRole
# Human Resources                   52
# Research Director                 80
# Sales Representative              83
# Manager                          102
# Healthcare Representative        131
# Manufacturing Director           145
# Laboratory Technician            259
# Research Scientist               292
# Sales Executive                  326

# %% [markdown]
# # Question(6)
# 6)**How** is the distace from home effect attrition?

# %%
df.groupby(['DistanceFromHome'] )[['Attrition']].count().sort_values(ascending = False , by ='Attrition')
# Out:
#                   Attrition
# DistanceFromHome
# 2                       211
# 1                       208
# 10                       86
# 9                        85
# 3                        84
# 7                        84
# 8                        80
# 5                        65
# 4                        64
# 6                        59
# 16                       32
# 11                       29
# 24                       28
# 23                       27
# 29                       27
# 18                       26
# 15                       26
# 20                       25
# 25                       25
# 26                       25
# 28                       23
# 19                       22
# 14                       21
# 17                       20
# 12                       20
# 22                       19
# 13                       19
# 21                       18
# 27                       12

# %%
sns.pairplot(X, hue="Attrition",plot_kws={'alpha': 0.7,'s':50},diag_kind='kde')

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
size = [882, 588]
labels = "Male", "Female"
colors = ['g', 'y']
explode = [0, 0.25]

plt.subplots(figsize=(7,6))
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('Representing Gender Attrition', fontsize = 25)
plt.legend(fontsize=16)
plt.show()

# %%
df['Attrition'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.YearsAtCompany.sort_values(ascending=True)
# Out:
# 1311     0
# 1371     0
# 460      0
# 1068     0
# 457      0
#         ..
# 561     34
# 1116    36
# 270     36
# 98      37
# 126     40
# Name: YearsAtCompany, Length: 1470, dtype: int64

# %%
###do histgram to campar the data from all columns with attrition

# %%
df.groupby('Attrition')[['StandardHours']].count()
# Out:
#            StandardHours
# Attrition
# No                  1233
# Yes                  237

# %%
df.groupby(['EducationField', 'Attrition']).count()
# Out:
#                             Age  BusinessTravel  DailyRate  Department  \
# EducationField   Attrition
# Human Resources  No          20              20         20          20
#                  Yes          7               7          7           7
# Life Sciences    No         517             517        517         517
#                  Yes         89              89         89          89
# Marketing        No         124             124        124         124
#                  Yes         35              35         35          35
# Medical          No         401             401        401         401
#                  Yes         63              63         63          63
# Other            No          71              71         71          71
#                  Yes         11              11         11          11
# Technical Degree No         100             100        100         100
#                  Yes         32              32         32          32
#
# ...

# %%
#groub_by_location = df.groupby('location')[['category']].count().sort_values('category', ascending=False)
#groub_by_location

# %%
df.groupby(['EducationField', 'Attrition'])["DistanceFromHome"].count()
# Out:
# EducationField    Attrition
# Human Resources   No            20
#                   Yes            7
# Life Sciences     No           517
#                   Yes           89
# Marketing         No           124
#                   Yes           35
# Medical           No           401
#                   Yes           63
# Other             No            71
#                   Yes           11
# Technical Degree  No           100
#                   Yes           32
# Name: DistanceFromHome, dtype: int64

# %%
def get_attr(attrition_value, second_column, second_column_value):
    return df.query(f"Attrition == '{attrition_value}' and {second_column} == '{second_column_value}'")

get_attr('No', 'Department', 'Sales')
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 18     53        No      Travel_Rarely       1219      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# 37     35        No      Travel_Rarely        890      Sales
# 39     33        No  Travel_Frequently       1141      Sales
# ...   ...       ...                ...        ...        ...
# 1453   36        No      Travel_Rarely       1120      Sales
# 1454   45        No      Travel_Rarely        374      Sales
# 1462   39        No      Travel_Rarely        722      Sales
# 1464   26        No      Travel_Rarely       1167      Sales
# 1468   49        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 18                   2          4  Life Sciences              1
# 27                   8          4      Marketing              1
# ...

# %%
len(df.query(f"Attrition == 'Yes' and EducationField == 'Human Resources'"))
# Out:
# 7

# %%
df.groupby('Attrition')[['DistanceFromHome']].
# Out:
#   File "<ipython-input-30-07da60ca04b9>", line 1
#     df.groupby('Attrition')[['DistanceFromHome']].
#                                                   ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
import seaborn as sns

# %%
sns.histplot(df['Attrition']);

# %%
df.to_csv('Fin_up.csv')

# %%
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1516a20b26b1> in <module>
# ----> 1 plt.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'
